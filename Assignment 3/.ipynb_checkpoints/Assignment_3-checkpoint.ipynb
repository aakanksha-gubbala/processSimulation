# %% [markdown]
# <p style="color:#737373; font-family:futura; font-size:200%;">Analysis of Lab Data</p>
# <p style="color:#737373; font-family:futura;">26 January 2021</p>

# %% [markdown]
# <p style="font-family:futura;">Experiment: Flow Through Pipes</p>
# The aim of the experiment is to determine the effect of Reynolds number on fanning friction factor for different flow regimes in a smooth pipe ($\epsilon / D \approx 0$). The experiment is performed for two process fluids - water and kerosene.
#
# <img src="pfd.png" style="float: center;" width=500 height=500/>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import scipy.optimize as opt
from scipy.constants import g
from sklearn.metrics import r2_score

# %config InlineBackend.figure_format = 'retina'

style.use("classic")

# %% [markdown]
# <p style="font-family:futura;">Formulae</p>
#
# $$\Delta P = \Delta H_m (\rho_m - \rho_f) g$$
#
# $$f_{experiment} = \frac{\Delta P D}{2 \rho v^2 L}$$
#
# For laminar regime:
#
# $$f = \frac{16}{Re}$$
#
# The Blasius equation for turbulent regime is
#
# $$f = 0.079 Re^{-0.25}$$
#
# The von Kármán-Nikuradse Correlation for turbulent regime is
#
# $$\frac{1}{\sqrt{f}} = 4\log{(Re\sqrt{f})} - 0.4$$

# %%
FluidProperties = {'Water': [1000, 8.5e-4],
                   'Kerosene': [820, 2.15e-3]}

def correlation_f_Re(df):
    f = df['Friction Factor']
    Re = df['Reynolds Number']
    if Re < 2100:
        f_corr = 16 / Re
    else:
        func = lambda x: 4 * np.log(Re * np.sqrt(x)) - 0.4 - 1 / np.sqrt(x)
        x0 = 0.001
        f_corr = opt.fsolve(func, x0, maxfev=1000000)[0]
    return f_corr


def f_Re(x, A, B):
    return A * x ** B

# %%
class FlowThroughPipes:
    def __init__(self, sheetname, D, L, fluid):
        self.df = pd.read_excel("FlowThroughPipes_DATA.xlsx", sheet_name=sheetname)
        self.D = D
        self.L = L
        self.fluid = fluid

    def CalculationTable(self):
        self.df.index += 1
        ManometerDensity = self.df['Manometer Fluid'].replace('Mercury', 13600.0).replace('CCl4', 1600.0)

        rho_f = FluidProperties[self.fluid][0]
        mu_f = FluidProperties[self.fluid][1]

        dHm = self.df['dHm (cm)']
        self.df['Delta P (Pa)'] = (dHm * 0.01) * (ManometerDensity - rho_f) * g

        Q = self.df['Q (LPM)'] * 0.001 / 60
        self.df['Velocity (m/s)'] = 4 * Q / (np.pi * self.D ** 2)

        self.df['Reynolds Number'] = self.D * self.df['Velocity (m/s)'] * rho_f / mu_f

        self.df['Friction Factor'] = self.df['Delta P (Pa)'] * self.D / (
                2 * rho_f * self.df['Velocity (m/s)'] ** 2 * self.L)

        self.df['f (correlations)'] = self.df.apply(correlation_f_Re, axis=1)

        self.df['Flow Regime'] = self.df['Reynolds Number'].map(lambda x: 'Laminar' if x < 2000 else 'Turbulent')

        return self.df.round({'Reynolds Number': 0, 'Velocity (m/s)': 3, 'Delta P (Pa)': 2})

    def Graphs(self):
        plt.figure(facecolor='white')
        plt.title(r"$f$ vs. $Re$ (%s)" % self.fluid, fontsize=18)
        plt.grid()
        plt.xlim(0, 1.1 * max(self.df['Reynolds Number']))
        plt.ylim(0, 1.1 * max(self.df['Friction Factor']))
        plt.xlabel(r"$Re$")
        plt.ylabel(r"$f$")
        try:
            lam = self.df[self.df['Flow Regime'] == 'Laminar']
            [A_lam, B_lam], params = opt.curve_fit(f_Re, lam['Reynolds Number'], lam['Friction Factor'])
            print("Laminar FLow: f = %0.4f Re^(%0.3f)" % (A_lam, B_lam))
            print("R2 = %0.4f\n" % r2_score(lam['Friction Factor'], f_Re(lam['Reynolds Number'], A_lam, B_lam)))

            plt.plot(lam['Reynolds Number'], f_Re(lam['Reynolds Number'], A_lam, B_lam),
                     color='blue', linestyle='--', label='Curve Fitting (laminar)')
            plt.scatter(lam['Reynolds Number'], lam['Friction Factor'],
                        color='blue', label='Experiment (laminar)')

            tur = self.df[self.df['Flow Regime'] == 'Turbulent']
            [A_tur, B_tur], params = opt.curve_fit(f_Re, tur['Reynolds Number'], tur['Friction Factor'])
            print("Turbulent Flow: f = %0.4f Re^(%0.3f)" % (A_tur, B_tur))
            print("R2 = %0.4f\n" % r2_score(tur['Friction Factor'], f_Re(tur['Reynolds Number'], A_tur, B_tur)))

            plt.plot(tur['Reynolds Number'], f_Re(tur['Reynolds Number'], A_tur, B_tur),
                     color='green', linestyle='--', label='Curve Fitting (laminar)')
            plt.scatter(tur['Reynolds Number'], tur['Friction Factor'],
                        color='green', label='Experiment (turbulent)')
            plt.legend(bbox_to_anchor=(1.26, 1), fontsize=6)

        except:
            tur = self.df[self.df['Flow Regime'] == 'Turbulent']
            [A_tur, B_tur], params = opt.curve_fit(f_Re, tur['Reynolds Number'], tur['Friction Factor'])
            print("Turbulent Flow: f = %0.4f Re^(%0.3f)" % (A_tur, B_tur))
            print("R2 = %0.4f\n" % r2_score(tur['Friction Factor'], f_Re(tur['Reynolds Number'], A_tur, B_tur)))

            plt.plot(tur['Reynolds Number'], f_Re(tur['Reynolds Number'], A_tur, B_tur),
                     color='green', linestyle='--', label='Curve Fitting (laminar)')
            plt.scatter(tur['Reynolds Number'], tur['Friction Factor'],
                        color='green', label='Experiment (turbulent)')
            plt.legend(bbox_to_anchor=(1.26, 1), fontsize=6)

# %% [markdown]
# ---
# We will analyze the first data set. The process fluid is water and the pipe dimensions are $D = 0.0127\ cm$, $L = 5\ m$.

# %%
Set1 = FlowThroughPipes('Set 1', 0.0127, 5.0, 'Water')
Set1.CalculationTable()
# Out:
#    Manometer Fluid  Q (LPM)  dHm (cm)  Delta P (Pa)  Velocity (m/s)  \
# 1             CCl4     0.25       0.2         11.77           0.033
# 2             CCl4     0.42       0.4         23.54           0.055
# 3             CCl4     0.67       0.6         35.30           0.088
# 4             CCl4     1.00       0.8         47.07           0.132
# 5             CCl4     2.00       3.4        200.06           0.263
# 6             CCl4     3.00       6.8        400.11           0.395
# 7             CCl4     4.00      11.4        670.77           0.526
# 8             CCl4     5.00      16.8        988.51           0.658
# 9             CCl4     6.00      23.2       1365.09           0.789
# 10            CCl4     7.00      30.2       1776.96           0.921
# 11            CCl4     8.00      38.2       2247.68           1.053
# 12            CCl4     9.00      47.0       2765.48           1.184
# 13            CCl4    10.00      56.4       3318.57           1.316
# 14            CCl4    11.00      66.8       3930.51           1.447
# 15         Mercury    12.00       3.8       4695.42           1.579
# 16         Mercury    13.00       4.2       5189.68           1.710
# 17         Mercury    14.00       4.8       5931.06           1.842
# 18         Mercury    15.00       5.4       6672.44           1.974
# 19         Mercury    20.00       9.0      11120.74           2.631
# 20         Mercury    30.00      18.4      22735.74           3.947
# 21         Mercury    40.00      30.4      37563.39           5.263
#
#     Reynolds Number  Friction Factor  f (correlations) Flow Regime
# 1             491.0         0.013814          0.032557     Laminar
# 2             826.0         0.009789          0.019379     Laminar
# 3            1317.0         0.005770          0.012148     Laminar
# 4            1966.0         0.003454          0.008139     Laminar
# 5            3932.0         0.003669          0.002355   Turbulent
# 6            5897.0         0.003262          0.002072   Turbulent
# 7            7863.0         0.003076          0.001899   Turbulent
# 8            9829.0         0.002901          0.001779   Turbulent
# 9           11795.0         0.002782          0.001689   Turbulent
# 10          13761.0         0.002661          0.001617   Turbulent
# 11          15726.0         0.002577          0.001559   Turbulent
# 12          17692.0         0.002505          0.001510   Turbulent
# 13          19658.0         0.002435          0.001468   Turbulent
# 14          21624.0         0.002383          0.001432   Turbulent
# 15          23589.0         0.002392          0.001399   Turbulent
# 16          25555.0         0.002253          0.001371   Turbulent
# 17          27521.0         0.002220          0.001345   Turbulent
# 18          29487.0         0.002176          0.001321   Turbulent
# 19          39316.0         0.002040          0.001230   Turbulent
# 20          58974.0         0.001853          0.001115   Turbulent
# 21          78631.0         0.001722          0.001043   Turbulent

# %%
Set1.Graphs()
# Out:
# Laminar FLow: f = 3.6340 Re^(-0.895)
# R2 = 0.9787
#
# Turbulent Flow: f = 0.0293 Re^(-0.252)
# R2 = 0.9980

# %% [markdown]
# ---
# Let's look at Set 2. The process fluid is still water but the pipe dimensions are $D = 0.0254\ cm$, $L = 2\ m$.

# %%
Set2 = FlowThroughPipes('Set 2', 0.0254, 2.0, 'Water')
Set2.CalculationTable()
# Out:
#    Manometer Fluid  Q (LPM)  dHm (cm)  Delta P (Pa)  Velocity (m/s)  \
# 1             CCl4        5       0.6         35.30           0.164
# 2             CCl4        6       0.8         47.07           0.197
# 3             CCl4        7       1.0         58.84           0.230
# 4             CCl4        8       1.2         70.61           0.263
# 5             CCl4        9       1.6         94.14           0.296
# 6             CCl4       10       1.8        105.91           0.329
# 7             CCl4       11       2.2        129.45           0.362
# 8             CCl4       12       2.6        152.98           0.395
# 9             CCl4       13       3.0        176.52           0.428
# 10            CCl4       14       3.4        200.06           0.460
# 11            CCl4       15       3.8        223.59           0.493
# 12            CCl4       20       6.2        364.81           0.658
# 13            CCl4       25       9.2        541.33           0.822
# 14            CCl4       30      12.6        741.38           0.987
# 15            CCl4       35      16.6        976.74           1.151
# 16            CCl4       40      20.8       1223.87           1.316
#
#     Reynolds Number  Friction Factor  f (correlations) Flow Regime
# 1            4914.0         0.008288          0.002193   Turbulent
# 2            5897.0         0.007675          0.002072   Turbulent
# 3            6880.0         0.007048          0.001977   Turbulent
# 4            7863.0         0.006475          0.001899   Turbulent
# 5            8846.0         0.006822          0.001834   Turbulent
# 6            9829.0         0.006216          0.001779   Turbulent
# 7           10812.0         0.006279          0.001731   Turbulent
# 8           11795.0         0.006236          0.001689   Turbulent
# 9           12778.0         0.006131          0.001651   Turbulent
# 10          13761.0         0.005991          0.001617   Turbulent
# 11          14743.0         0.005833          0.001587   Turbulent
# 12          19658.0         0.005353          0.001468   Turbulent
# 13          24572.0         0.005084          0.001385   Turbulent
# 14          29487.0         0.004835          0.001321   Turbulent
# 15          34401.0         0.004680          0.001271   Turbulent
# 16          39316.0         0.004490          0.001230   Turbulent

# %%
Set2.Graphs()
# Out:
# Turbulent Flow: f = 0.0858 Re^(-0.280)
# R2 = 0.9680

# %% [markdown]
# ---
# Lastly, let's look at Set 3. The process fluid is now kerosene and the pipe dimensions are $D = 0.0254\ cm$, $L = 2\ m$.

# %%
Set3 = FlowThroughPipes('Set 3', 0.0254, 2.0, 'Kerosene')
Set3.CalculationTable()
# Out:
#   Manometer Fluid  Q (LPM)  dHm (cm)  Delta P (Pa)  Velocity (m/s)  \
# 1            CCl4       13       2.4        183.58           0.428
# 2            CCl4       14       2.8        214.18           0.460
# 3            CCl4       15       3.2        244.77           0.493
# 4            CCl4       20       5.2        397.76           0.658
# 5            CCl4       25       7.6        581.34           0.822
# 6            CCl4       30      10.6        810.81           0.987
# 7            CCl4       35      13.8       1055.59           1.151
# 8            CCl4       40      17.4       1330.96           1.316
#
#    Reynolds Number  Friction Factor  f (correlations) Flow Regime
# 1           4142.0         0.007775          0.002316   Turbulent
# 2           4461.0         0.007822          0.002261   Turbulent
# 3           4780.0         0.007787          0.002212   Turbulent
# 4           6373.0         0.007118          0.002023   Turbulent
# 5           7966.0         0.006658          0.001892   Turbulent
# 6           9559.0         0.006448          0.001793   Turbulent
# 7          11152.0         0.006168          0.001716   Turbulent
# 8          12746.0         0.005954          0.001652   Turbulent

# %%
Set3.Graphs()
# Out:
# Turbulent Flow: f = 0.0649 Re^(-0.252)
# R2 = 0.9879

# %% [markdown]
# ---
